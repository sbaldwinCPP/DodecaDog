# %% [markdown]
# File/Folder Dialogs

# %%
from snippets import QuickFile

#   alt import method
#import snippets as sn
#sn.QuickFile()
#fig, ax = sn.QuickScatter()
# Out:
# ''

# %% [markdown]
# Tests

# %%
QuickFile()
#QuickFile(multi=True)
#QuickFile(folder=True)
# Out:
# 'C:/Users/super/Documents/GitHub/DodecaDog/LICENSE'

# %%
ftypes = [
        ('Inp files', '*inp'),
        ('Text files', '*.txt'),
        ('Excel files', '*.xlsx')]
QuickFile(ftypes=ftypes, AllFileTypes=False)
# Out:
# ''

# %% [markdown]
# PLOTS

# %%
import numpy as np
from snippets import QuickScatter

n = 50
x = np.random.rand(n)
y = np.random.rand(n)
z = np.random.rand(n)

fig, ax = QuickScatter(x,y,z)

# %%
fig, ax = QuickScatter(x,y,z,
        cm='cool', 
        vmin=-.5, 
        vmax=1.5, 
        ticks=[0, 1],
        xlabel='Random X',
        ylabel='Random Y',
        units='Units',
        pad=0.2)
